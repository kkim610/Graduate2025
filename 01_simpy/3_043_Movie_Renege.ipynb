# %% [markdown]
# # Movie Renege
# Covers:
#
# - Resources: Resource
#
# - Condition events
#
# - Shared events
#
# This examples models a movie theater with one ticket counter selling tickets for three movies (next show only). People arrive at random times and try to buy a random number (1–6) of tickets for a random movie. When a movie is sold out, all people waiting to buy a ticket for that movie renege (leave the queue).
#
# The movie theater is just a container for all the related data (movies, the counter, tickets left, collected data, …). The counter is a Resource with a capacity of one.
#
# The moviegoer process starts waiting until either it’s his turn (it acquires the counter resource) or until the sold out signal is triggered. If the latter is the case it reneges (leaves the queue). If it gets to the counter, it tries to buy some tickets. This might not be successful, e.g. if the process tries to buy 5 tickets but only 3 are left. If less than two tickets are left after the ticket purchase, the sold out signal is triggered.
#
# Moviegoers are generated by the customer arrivals process. It also chooses a movie and the number of tickets for the moviegoer.

# %%
"""
Movie renege example

Covers:

- Resources: Resource
- Condition events
- Shared events

Scenario:
  A movie theatre has one ticket counter selling tickets for three
  movies (next show only). When a movie is sold out, all people waiting
  to buy tickets for that movie renege (leave queue).

"""

from __future__ import annotations

import random
from typing import Dict, List, NamedTuple, Optional

import simpy

RANDOM_SEED = 42
TICKETS = 50  # Number of tickets per movie
SELLOUT_THRESHOLD = 2  # Fewer tickets than this is a sellout
SIM_TIME = 120  # Simulate until ####################################################


def moviegoer(env, movie, num_tickets, theater):
    """A moviegoer tries to by a number of tickets (*num_tickets*) for
    a certain *movie* in a *theater*.

    If the movie becomes sold out, she leaves the theater. If she gets
    to the counter, she tries to buy a number of tickets. If not enough
    tickets are left, she argues with the teller and leaves.

    If at most one ticket is left after the moviegoer bought her
    tickets, the *sold out* event for this movie is triggered causing
    all remaining moviegoers to leave.

    """
    with theater.counter.request() as my_turn:
        # Wait until it's our turn or until the movie is sold out
        result = yield my_turn | theater.sold_out[movie]

        # Check if it's our turn or if movie is sold out
        if my_turn not in result:
            theater.num_renegers[movie] += 1
            return

        # Check if enough tickets left.
        if theater.available[movie] < num_tickets:
            # Moviegoer leaves after some discussion
            print("@@@@@@@@@ fail to buy tickets!!", "customer wants", movie, num_tickets, "tickets. But", theater.available[movie], "tickets are remained.\n")

            yield env.timeout(0.5)
            return

        # Buy tickets
        theater.available[movie] -= num_tickets
        print(f"customer bought !!") 
        print(movie, "theater.available[movie]", theater.available[movie], "\n")

        if theater.available[movie] < SELLOUT_THRESHOLD:
            print("SOLD OUT movie", movie, "theater.available[movie]", theater.available[movie], "\n")
            # Trigger the "sold out" event for the movie
            theater.sold_out[movie].succeed()
            theater.when_sold_out[movie] = env.now
            theater.available[movie] = 0
        #yield env.timeout(1)


def customer_arrivals(env, theater):
    """Create new *moviegoers* until the sim time reaches 120."""
    while True:
        yield env.timeout(random.expovariate(1 / 0.5))
        movie = random.choice(theater.movies)
        num_tickets = random.randint(1, 6)
        print("customer wants  movie", movie, num_tickets, "tickets" ) ###############################################################
        #print("movie", movie, "num_tickets",num_tickets, "at {:.2}".format(env.now))
        #print(f"{movie} : {theater.available[movie]} tickets available !!!")
        
        if theater.available[movie]:
            env.process(moviegoer(env, movie, num_tickets, theater))
            #print(f"customer bought !!")           
            #print(f"{movie} : {theater.available[movie] - num_tickets} tickets remaining !!! \n")
            
        else:          
            print("!!! unavailable !!! \n")
        
class Theater(NamedTuple):      ####################### from typing import NamedTuple 참고하세요. ###################################################
    counter: simpy.Resource
    movies: List[str]
    available: Dict[str, int]
    sold_out: Dict[str, simpy.Event]
    when_sold_out: Dict[str, Optional[float]]
    num_renegers: Dict[str, int]


# Setup and start the simulation
print('Movie renege')
random.seed(RANDOM_SEED)
env = simpy.Environment()

# Create movie theater
movies = ['Python Unchained', 'Kill Process', 'Pulp Implementation']
theater = Theater(
    counter=simpy.Resource(env, capacity=1),
    movies=movies,
    available={movie: TICKETS for movie in movies},
    sold_out={movie: env.event() for movie in movies},
    when_sold_out={movie: None for movie in movies},
    num_renegers={movie: 0 for movie in movies},
)

# Start process and run
env.process(customer_arrivals(env, theater))
env.run(until=SIM_TIME)

# Analysis/results
for movie in movies:
    if theater.sold_out[movie]:
        sellout_time = theater.when_sold_out[movie]
        num_renegers = theater.num_renegers[movie]
        '''
        print(
            f'Movie "{movie}" sold out {sellout_time:.1f} minutes '
            f'after ticket counter opening.'
        )
        print(f'  Number of people leaving queue when film sold out: {num_renegers}')
        '''
# Out:
# Movie renege
# customer wants  movie Python Unchained 6 tickets
# customer bought !!
# Python Unchained theater.available[movie] 44
#
# customer wants  movie Python Unchained 2 tickets
# customer bought !!
# Python Unchained theater.available[movie] 42
#
# customer wants  movie Pulp Implementation 6 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 44
#
# customer wants  movie Python Unchained 5 tickets
# customer bought !!
# Python Unchained theater.available[movie] 37
#
# customer wants  movie Python Unchained 1 tickets
# customer bought !!
# Python Unchained theater.available[movie] 36
#
# customer wants  movie Pulp Implementation 5 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 39
#
# customer wants  movie Python Unchained 6 tickets
# customer bought !!
# Python Unchained theater.available[movie] 30
#
# customer wants  movie Pulp Implementation 4 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 35
#
# customer wants  movie Pulp Implementation 3 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 32
#
# customer wants  movie Python Unchained 2 tickets
# customer bought !!
# Python Unchained theater.available[movie] 28
#
# customer wants  movie Kill Process 3 tickets
# customer bought !!
# Kill Process theater.available[movie] 47
#
# customer wants  movie Kill Process 1 tickets
# customer bought !!
# Kill Process theater.available[movie] 46
#
# customer wants  movie Python Unchained 3 tickets
# customer bought !!
# Python Unchained theater.available[movie] 25
#
# customer wants  movie Pulp Implementation 3 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 29
#
# customer wants  movie Pulp Implementation 4 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 25
#
# customer wants  movie Kill Process 1 tickets
# customer bought !!
# Kill Process theater.available[movie] 45
#
# customer wants  movie Pulp Implementation 5 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 20
#
# customer wants  movie Kill Process 5 tickets
# customer bought !!
# Kill Process theater.available[movie] 40
#
# customer wants  movie Python Unchained 1 tickets
# customer bought !!
# Python Unchained theater.available[movie] 24
#
# customer wants  movie Kill Process 1 tickets
# customer bought !!
# Kill Process theater.available[movie] 39
#
# customer wants  movie Python Unchained 4 tickets
# customer bought !!
# Python Unchained theater.available[movie] 20
#
# customer wants  movie Pulp Implementation 3 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 17
#
# customer wants  movie Kill Process 2 tickets
# customer bought !!
# Kill Process theater.available[movie] 37
#
# customer wants  movie Pulp Implementation 6 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 11
#
# customer wants  movie Pulp Implementation 6 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 5
#
# customer wants  movie Pulp Implementation 2 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 3
#
# customer wants  movie Kill Process 3 tickets
# customer bought !!
# Kill Process theater.available[movie] 34
#
# customer wants  movie Pulp Implementation 6 tickets
# @@@@@@@@@ fail to buy tickets!! customer wants Pulp Implementation 6 tickets. But 3 tickets are remained.
#
# customer wants  movie Pulp Implementation 3 tickets
# customer bought !!
# Pulp Implementation theater.available[movie] 0
#
# SOLD OUT movie Pulp Implementation theater.available[movie] 0
#
# customer wants  movie Python Unchained 2 tickets
# customer bought !!
# Python Unchained theater.available[movie] 18
#
# customer wants  movie Kill Process 4 tickets
# customer bought !!
# Kill Process theater.available[movie] 30
#
# customer wants  movie Python Unchained 5 tickets
# customer bought !!
# Python Unchained theater.available[movie] 13
#
# customer wants  movie Kill Process 2 tickets
# customer bought !!
# Kill Process theater.available[movie] 28
#
# customer wants  movie Kill Process 6 tickets
# customer bought !!
# Kill Process theater.available[movie] 22
#
# customer wants  movie Kill Process 2 tickets
# customer bought !!
# Kill Process theater.available[movie] 20
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# customer bought !!
# Kill Process theater.available[movie] 17
#
# customer wants  movie Python Unchained 5 tickets
# customer bought !!
# Python Unchained theater.available[movie] 8
#
# customer wants  movie Python Unchained 1 tickets
# customer bought !!
# Python Unchained theater.available[movie] 7
#
# customer wants  movie Python Unchained 6 tickets
# customer bought !!
# Python Unchained theater.available[movie] 1
#
# SOLD OUT movie Python Unchained theater.available[movie] 1
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# customer bought !!
# Kill Process theater.available[movie] 12
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# customer bought !!
# Kill Process theater.available[movie] 6
#
# customer wants  movie Kill Process 4 tickets
# customer bought !!
# Kill Process theater.available[movie] 2
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# @@@@@@@@@ fail to buy tickets!! customer wants Kill Process 5 tickets. But 2 tickets are remained.
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# @@@@@@@@@ fail to buy tickets!! customer wants Kill Process 6 tickets. But 2 tickets are remained.
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# customer bought !!
# Kill Process theater.available[movie] 1
#
# SOLD OUT movie Kill Process theater.available[movie] 1
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 4 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 6 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 5 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 2 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
#
# customer wants  movie Pulp Implementation 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Python Unchained 3 tickets
# !!! unavailable !!!
#
# customer wants  movie Kill Process 1 tickets
# !!! unavailable !!!
