# %% [markdown]
# # Machine Shop
# Covers:
#
# - Interrupts
#
# - Resources: PreemptiveResource
#
# This example comprises a workshop with n identical machines. A stream of jobs (enough to keep the machines busy) arrives. Each machine breaks down periodically. Repairs are carried out by one repairman. The repairman has other, less important tasks to perform, too. Broken machines preempt theses tasks. The repairman continues them when he is done with the machine repair. The workshop works continuously.
#
# A machine has two processes: working implements the actual behaviour of the machine (producing parts). break_machine periodically interrupts the working process to simulate the machine failure.
#
# The repairman’s other job is also a process (implemented by other_job). The repairman itself is a PreemptiveResource with a capacity of 1. The machine repairing has a priority of 1, while the other job has a priority of 2 (the smaller the number, the higher the priority).

# %% [markdown]
# 우선순위가 높다 = 먼저 처리한다 = priority 1 이 priority 2 보다 우선 순위가 높다.

# %%
"""
Machine shop example

Covers:

- Interrupts
- Resources: PreemptiveResource

Scenario:
  A workshop has *n* identical machines. A stream of jobs (enough to
  keep the machines busy) arrives. Each machine breaks down
  periodically. Repairs are carried out by one repairman. The repairman
  has other, less important tasks to perform, too. Broken machines
  preempt these tasks. The repairman continues them when he is done
  with the machine repair. The workshop works continuously.

"""

import random

import simpy

# fmt: off
RANDOM_SEED = 42
PT_MEAN = 10.0         # Avg. processing time in minutes
PT_SIGMA = 2.0         # Sigma of processing time
MTTF = 300.0           # Mean time to failure in minutes
BREAK_MEAN = 1 / MTTF  # Param. for expovariate distribution
REPAIR_TIME = 30.0     # Time it takes to repair a machine in minutes
JOB_DURATION = 30.0    # Duration of other jobs in minutes
NUM_MACHINES = 10      # Number of machines in the machine shop   ##############################
WEEKS = 4              # Simulation time in weeks
SIM_TIME =  WEEKS * 7 * 24 * 60  # Simulation time in minutes  
# fmt: on


def time_per_part():
    """Return actual processing time for a concrete part."""
    t = random.normalvariate(PT_MEAN, PT_SIGMA)
    # The normalvariate can be negative, but we want only positive times.
    while t <= 0:
        t = random.normalvariate(PT_MEAN, PT_SIGMA)
    return t


def time_to_failure():
    """Return time until next failure for a machine."""
    return random.expovariate(BREAK_MEAN)


class Machine:
    """A machine produces parts and my get broken every now and then.

    If it breaks, it requests a *repairman* and continues the production
    after the it is repaired.

    A machine has a *name* and a number of *parts_made* thus far.

    """

    def __init__(self, env, name, repairman):
        self.env = env
        self.name = name
        self.parts_made = 0
        self.broken = False
        self.broken_count = 0 
        # Start "working" and "break_machine" processes for this machine.
        self.process = env.process(self.working(repairman))
        env.process(self.break_machine())

    def working(self, repairman):
        """Produce parts as long as the simulation runs.

        While making a part, the machine may break multiple times.
        Request a repairman when this happens.

        """
        while True:
            # Start making a new part
            done_in = time_per_part()  # 현 부품의 작업시간은 N(10,2)로부터 random sampling
            while done_in:
                start = self.env.now
                try:
                    # Working on the part
                    yield self.env.timeout(done_in)
                    done_in = 0  # Set to 0 to exit while loop.

                except simpy.Interrupt:
                    self.broken = True
                    self.broken_count += 1   
                    print(f"The machine start processing current part at {start}.")
                    print(f"It will take {done_in} min.")
                    print(f"But the machine was broken at {self.env.now}.")
                    
                    done_in -= self.env.now - start  # How much time left? 현 부품의 남은 처리시간 (기계고장으로 인함)
                    print(f"The remaining processing is {done_in}")

                    
                    # Request a repairman. This will preempt its "other_job".
                    with repairman.request(priority=1) as req:
                        yield req
                        
                        yield self.env.timeout(REPAIR_TIME) ############# REPAIR_TIME = 30 min
                    
                    print(f"The machine was repaired at {self.env.now}")
                    
                    self.broken = False

            # Part is done.
            self.parts_made += 1

    def break_machine(self):
        """Break the machine every now and then."""
        while True:
            yield self.env.timeout(time_to_failure()) 
            #yield self.env.timeout(SIM_TIME+1) 
            
            if not self.broken:
                # Only break the machine if it is currently working.
                print("machine broken !!!!!!!!! at", env.now)
                self.process.interrupt()


def other_jobs(env, repairman):
    """The repairman's other (unimportant) job."""
    print("other_jobs at", env.now)
    while True:
        # Start a new job
        done_in = JOB_DURATION   #### priority 2 의 작업시간은 30분으로 일정함.
        while done_in:
            # Retry the job until it is done.
            # Its priority is lower than that of machine repairs.
            print("done_in at", env.now)
            with repairman.request(priority=2) as req:
                yield req
                start = env.now
                try:
                    yield env.timeout(done_in)
                    done_in = 0
                    print("leave other_jobs at", env.now)
                except simpy.Interrupt:
                    print("interrupted during other_jobs at", env.now)
                    
                    done_in -= env.now - start


# Setup and start the simulation
print('Machine shop')
random.seed(RANDOM_SEED)  # This helps to reproduce the results

# Create an environment and start the setup process
env = simpy.Environment()
repairman = simpy.PreemptiveResource(env, capacity=1)
machines = [Machine(env, f'Machine {i}', repairman) for i in range(NUM_MACHINES)]
env.process(other_jobs(env, repairman))

# Execute!
env.run(until=SIM_TIME)

# Analysis/results
#print(f'Machine shop results after {WEEKS} weeks')
print(f'Machine shop results after {SIM_TIME} minutes')
for machine in machines:
    print(f'{machine.name} made {machine.parts_made} parts.')

for machine in machines: 
    print(f'{machine.name} has broken {machine.broken_count} times.')
# Out:
# Machine shop
# other_jobs at 0
# done_in at 0
# machine broken !!!!!!!!! at 1.9559905662800305
# The machine start processing current part at 0.
# It will take 11.607158803243346 min.
# But the machine was broken at 1.9559905662800305.
# The remaining processing is 9.651168236963315
# interrupted during other_jobs at 1.9559905662800305
# done_in at 1.9559905662800305
# machine broken !!!!!!!!! at 30.51560549868949
# The machine start processing current part at 28.13195947898992.
# It will take 8.018075837441106 min.
# But the machine was broken at 30.51560549868949.
# The remaining processing is 5.6344298177415375
# The machine was repaired at 31.95599056628003
# The machine was repaired at 61.95599056628003
# machine broken !!!!!!!!! at 66.50750074910412
# The machine start processing current part at 56.86768924291138.
# It will take 10.393554897733017 min.
# But the machine was broken at 66.50750074910412.
# The remaining processing is 0.753743391540274
# interrupted during other_jobs at 66.50750074910412
# done_in at 66.50750074910412
# machine broken !!!!!!!!! at 66.5116438186494
# The machine start processing current part at 61.95599056628003.
# It will take 5.6344298177415375 min.
# But the machine was broken at 66.5116438186494.
# The remaining processing is 1.0787765653721628
# machine broken !!!!!!!!! at 74.0150087879473
# The machine start processing current part at 73.52143639741469.
# It will take 8.98716283808292 min.
# But the machine was broken at 74.0150087879473.
# The remaining processing is 8.493590447550314
# machine broken !!!!!!!!! at 74.70792569004709
# The machine start processing current part at 73.62054041181219.
# It will take 12.607879257690868 min.
# But the machine was broken at 74.70792569004709.
# The remaining processing is 11.520493979455964
# machine broken !!!!!!!!! at 96.48721922248967
# The machine start processing current part at 94.51485487323139.
# It will take 7.852551496612461 min.
# But the machine was broken at 96.48721922248967.
# The remaining processing is 5.880187147354176
# The machine was repaired at 96.50750074910412
# machine broken !!!!!!!!! at 124.76852594957427
# The machine start processing current part at 114.3829648893369.
# It will take 10.937515043302916 min.
# But the machine was broken at 124.76852594957427.
# The remaining processing is 0.5519539830655518
# The machine was repaired at 126.50750074910412
# machine broken !!!!!!!!! at 144.65839542097544
# The machine start processing current part at 138.49400442506246.
# It will take 12.012660250663535 min.
# But the machine was broken at 144.65839542097544.
# The remaining processing is 5.848269254750553
# The machine was repaired at 156.5075007491041
# The machine was repaired at 186.5075007491041
# The machine was repaired at 216.5075007491041
# The machine was repaired at 246.5075007491041
# machine broken !!!!!!!!! at 255.29154196370826
# The machine start processing current part at 247.4534832482625.
# It will take 12.935949427150538 min.
# But the machine was broken at 255.29154196370826.
# The remaining processing is 5.097890711704784
# The machine was repaired at 276.5075007491041
# machine broken !!!!!!!!! at 292.1892538199638
# The machine start processing current part at 287.6394186136349.
# It will take 8.993954320867566 min.
# But the machine was broken at 292.1892538199638.
# The remaining processing is 4.444119114538658
# machine broken !!!!!!!!! at 297.7453178139996
# The machine start processing current part at 289.25655389757657.
# It will take 8.950036972768661 min.
# But the machine was broken at 297.7453178139996.
# The remaining processing is 0.4612730563456502
# The machine was repaired at 306.5075007491041
# The machine was repaired at 336.5075007491041
# machine broken !!!!!!!!! at 338.7519026395778
# The machine start processing current part at 333.2401097717488.
# It will take 12.71348928031674 min.
# But the machine was broken at 338.7519026395778.
# The remaining processing is 7.201696412487738
# machine broken !!!!!!!!! at 359.3719880381553
# The machine start processing current part at 354.798705489025.
# It will take 12.61151633365301 min.
# But the machine was broken at 359.3719880381553.
# The remaining processing is 8.038233784522726
# The machine was repaired at 366.5075007491041
# The machine was repaired at 396.5075007491041
# The machine was repaired at 426.5075007491041
# leave other_jobs at 450.0
# done_in at 450.0
# machine broken !!!!!!!!! at 458.2865591938254
# The machine start processing current part at 451.0081779531995.
# It will take 9.675868006474875 min.
# But the machine was broken at 458.2865591938254.
# The remaining processing is 2.397486765848985
# interrupted during other_jobs at 458.2865591938254
# done_in at 458.2865591938254
# The machine was repaired at 488.2865591938254
# machine broken !!!!!!!!! at 493.71898182157753
# The machine start processing current part at 483.1894966221367.
# It will take 13.467514355283452 min.
# But the machine was broken at 493.71898182157753.
# The remaining processing is 2.93802915584261
# interrupted during other_jobs at 493.71898182157753
# done_in at 493.71898182157753
# The machine was repaired at 523.7189818215775
# machine broken !!!!!!!!! at 532.8306247227836
# The machine start processing current part at 526.6570109774201.
# It will take 8.751519465599172 min.
# But the machine was broken at 532.8306247227836.
# The remaining processing is 2.5779057202357034
# interrupted during other_jobs at 532.8306247227836
# done_in at 532.8306247227836
# The machine was repaired at 562.8306247227836
# leave other_jobs at 570.0
# done_in at 570.0
# machine broken !!!!!!!!! at 576.6111383049667
# The machine start processing current part at 569.8940044277157.
# It will take 7.319240166318718 min.
# But the machine was broken at 576.6111383049667.
# The remaining processing is 0.6021062890676596
# interrupted during other_jobs at 576.6111383049667
# done_in at 576.6111383049667
# machine broken !!!!!!!!! at 602.8333082801155
# The machine start processing current part at 602.656006532557.
# It will take 12.88155651428451 min.
# But the machine was broken at 602.8333082801155.
# The remaining processing is 12.704254766725965
# The machine was repaired at 606.6111383049667
# machine broken !!!!!!!!! at 631.8868509765407
# The machine start processing current part at 631.379270705454.
# It will take 9.718748310231963 min.
# But the machine was broken at 631.8868509765407.
# The remaining processing is 9.211168039145281
# The machine was repaired at 636.6111383049667
# The machine was repaired at 666.6111383049667
# machine broken !!!!!!!!! at 666.7538238241405
# The machine start processing current part at 657.1196515704493.
# It will take 10.613539581255786 min.
# But the machine was broken at 666.7538238241405.
# The remaining processing is 0.9793673275645958
# interrupted during other_jobs at 666.7538238241405
# done_in at 666.7538238241405
# machine broken !!!!!!!!! at 683.9690923677623
# The machine start processing current part at 678.6801178456534.
# It will take 12.46516036962226 min.
# But the machine was broken at 683.9690923677623.
# The remaining processing is 7.176185847513359
# The machine was repaired at 696.7538238241405
# machine broken !!!!!!!!! at 718.8189426927836
# The machine start processing current part at 708.1010034032217.
# It will take 11.917138197431523 min.
# But the machine was broken at 718.8189426927836.
# The remaining processing is 1.1991989078696683
# The machine was repaired at 726.7538238241405
# The machine was repaired at 756.7538238241405
# leave other_jobs at 780.0
# done_in at 780.0
# machine broken !!!!!!!!! at 784.3824632272394
# The machine start processing current part at 783.5951043014611.
# It will take 8.395813051995573 min.
# But the machine was broken at 784.3824632272394.
# The remaining processing is 7.608454126217238
# interrupted during other_jobs at 784.3824632272394
# done_in at 784.3824632272394
# The machine was repaired at 814.3824632272394
# leave other_jobs at 840.0
# done_in at 840.0
# machine broken !!!!!!!!! at 852.1020353931852
# The machine start processing current part at 847.5545710700186.
# It will take 7.666141362559847 min.
# But the machine was broken at 852.1020353931852.
# The remaining processing is 3.118677039393196
# interrupted during other_jobs at 852.1020353931852
# done_in at 852.1020353931852
# machine broken !!!!!!!!! at 872.2124584207991
# The machine start processing current part at 865.6655458795509.
# It will take 13.775721709552858 min.
# But the machine was broken at 872.2124584207991.
# The remaining processing is 7.228809168304696
# The machine was repaired at 882.1020353931852
# machine broken !!!!!!!!! at 906.2813357268662
# The machine start processing current part at 897.0060439674312.
# It will take 9.993061065249544 min.
# But the machine was broken at 906.2813357268662.
# The remaining processing is 0.7177693058144943
# The machine was repaired at 912.1020353931852
# The machine was repaired at 942.1020353931852
# leave other_jobs at 960.0
# done_in at 960.0
# machine broken !!!!!!!!! at 968.161965573369
# The machine start processing current part at 964.4351360831077.
# It will take 9.927250880273334 min.
# But the machine was broken at 968.161965573369.
# The remaining processing is 6.200421390012082
# interrupted during other_jobs at 968.161965573369
# done_in at 968.161965573369
# machine broken !!!!!!!!! at 979.32271398573
# The machine start processing current part at 974.6394173601374.
# It will take 11.71684960100133 min.
# But the machine was broken at 979.32271398573.
# The remaining processing is 7.033552975408655
# The machine was repaired at 998.161965573369
# machine broken !!!!!!!!! at 1004.4354835151722
# The machine start processing current part at 1004.3623869633811.
# It will take 13.403277332854673 min.
# But the machine was broken at 1004.4354835151722.
# The remaining processing is 13.330180781063591
# The machine was repaired at 1028.161965573369
# The machine was repaired at 1058.161965573369
# leave other_jobs at 1080.0
# done_in at 1080.0
# machine broken !!!!!!!!! at 1084.8645557070058
# The machine start processing current part at 1077.741482828223.
# It will take 8.636599934016662 min.
# But the machine was broken at 1084.8645557070058.
# The remaining processing is 1.5135270552339115
# interrupted during other_jobs at 1084.8645557070058
# done_in at 1084.8645557070058
# machine broken !!!!!!!!! at 1098.7693105654862
# The machine start processing current part at 1094.3858842664604.
# It will take 12.110380094202343 min.
# But the machine was broken at 1098.7693105654862.
# The remaining processing is 7.726953795176529
# The machine was repaired at 1114.8645557070058
# machine broken !!!!!!!!! at 1117.282860141151
# The machine start processing current part at 1116.3780827622397.
# It will take 10.326748151282494 min.
# But the machine was broken at 1117.282860141151.
# The remaining processing is 9.421970772371118
# The machine was repaired at 1144.8645557070058
# The machine was repaired at 1174.8645557070058
# machine broken !!!!!!!!! at 1197.6074192036624
# The machine start processing current part at 1196.7786543174786.
# It will take 11.690536543617739 min.
# But the machine was broken at 1197.6074192036624.
# The remaining processing is 10.861771657433977
# interrupted during other_jobs at 1197.6074192036624
# done_in at 1197.6074192036624
# The machine was repaired at 1227.6074192036624
# leave other_jobs at 1230.0
# done_in at 1230.0
# machine broken !!!!!!!!! at 1255.8416326047864
# The machine start processing current part at 1249.2218038316898.
# It will take 11.757251655637955 min.
# But the machine was broken at 1255.8416326047864.
# The remaining processing is 5.13742288254144
# interrupted during other_jobs at 1255.8416326047864
# done_in at 1255.8416326047864
# The machine was repaired at 1285.8416326047864
# leave other_jobs at 1290.0
# done_in at 1290.0
# leave other_jobs at 1320.0
# done_in at 1320.0
# machine broken !!!!!!!!! at 1332.0876867260201
# The machine start processing current part at 1321.6688674832378.
# It will take 17.066833671379673 min.
# But the machine was broken at 1332.0876867260201.
# The remaining processing is 6.648014428597353
# interrupted during other_jobs at 1332.0876867260201
# done_in at 1332.0876867260201
# machine broken !!!!!!!!! at 1340.5946298750082
# The machine start processing current part at 1335.9993286123251.
# It will take 11.882202491174255 min.
# But the machine was broken at 1340.5946298750082.
# The remaining processing is 7.286901228491203
# machine broken !!!!!!!!! at 1343.5958095169722
# The machine start processing current part at 1334.7990521820568.
# It will take 10.116999384113772 min.
# But the machine was broken at 1343.5958095169722.
# The remaining processing is 1.3202420491984164
# machine broken !!!!!!!!! at 1349.4986060537565
# The machine start processing current part at 1340.8701598215032.
# It will take 11.011047041921605 min.
# But the machine was broken at 1349.4986060537565.
# The remaining processing is 2.3826008096683235
# machine broken !!!!!!!!! at 1356.151479800032
# The machine start processing current part at 1348.4367308845226.
# It will take 10.30513050032066 min.
# But the machine was broken at 1356.151479800032.
# The remaining processing is 2.59038158481137
# The machine was repaired at 1362.0876867260201
# The machine was repaired at 1392.0876867260201
# The machine was repaired at 1422.0876867260201
# machine broken !!!!!!!!! at 1440.0332057540506
# The machine start processing current part at 1434.6364323471803.
# It will take 8.693616476372979 min.
# But the machine was broken at 1440.0332057540506.
# The remaining processing is 3.2968430695026267
# The machine was repaired at 1452.0876867260201
# The machine was repaired at 1482.0876867260201
# The machine was repaired at 1512.0876867260201
# leave other_jobs at 1530.0
# done_in at 1530.0
# leave other_jobs at 1560.0
# done_in at 1560.0
# leave other_jobs at 1590.0
# done_in at 1590.0
# leave other_jobs at 1620.0
# done_in at 1620.0
# machine broken !!!!!!!!! at 1639.923005056284
# The machine start processing current part at 1638.8751905560587.
# It will take 10.09166901602087 min.
# But the machine was broken at 1639.923005056284.
# The remaining processing is 9.043854515795584
# interrupted during other_jobs at 1639.923005056284
# done_in at 1639.923005056284
# machine broken !!!!!!!!! at 1644.1533380835385
# The machine start processing current part at 1634.9482647803304.
# It will take 10.430469015127542 min.
# But the machine was broken at 1644.1533380835385.
# The remaining processing is 1.2253957119194325
# The machine was repaired at 1669.923005056284
# machine broken !!!!!!!!! at 1675.273814213029
# The machine start processing current part at 1668.783797359986.
# It will take 12.489262140303872 min.
# But the machine was broken at 1675.273814213029.
# The remaining processing is 5.999245287260855
# machine broken !!!!!!!!! at 1686.1354484394672
# The machine start processing current part at 1676.0618780936534.
# It will take 12.05838900222224 min.
# But the machine was broken at 1686.1354484394672.
# The remaining processing is 1.9848186564084624
# The machine was repaired at 1699.923005056284
# The machine was repaired at 1729.923005056284
# machine broken !!!!!!!!! at 1738.4894174084034
# The machine start processing current part at 1737.3312498711027.
# It will take 9.73818157526715 min.
# But the machine was broken at 1738.4894174084034.
# The remaining processing is 8.580014037966508
# The machine was repaired at 1759.923005056284
# machine broken !!!!!!!!! at 1770.49841251712
# The machine start processing current part at 1765.959800171455.
# It will take 10.014007632049218 min.
# But the machine was broken at 1770.49841251712.
# The remaining processing is 5.47539528638433
# The machine was repaired at 1789.923005056284
# The machine was repaired at 1819.923005056284
# machine broken !!!!!!!!! at 1821.5048489198523
# The machine start processing current part at 1814.1632649927465.
# It will take 8.725907958578457 min.
# But the machine was broken at 1821.5048489198523.
# The remaining processing is 1.3843240314726266
# interrupted during other_jobs at 1821.5048489198523
# done_in at 1821.5048489198523
# machine broken !!!!!!!!! at 1841.5511143976587
# The machine start processing current part at 1834.0584348408436.
# It will take 8.816652323039879 min.
# But the machine was broken at 1841.5511143976587.
# The remaining processing is 1.3239727662247596
# The machine was repaired at 1851.5048489198523
# machine broken !!!!!!!!! at 1852.3105324087724
# The machine start processing current part at 1847.6312329874133.
# It will take 11.483399099704833 min.
# But the machine was broken at 1852.3105324087724.
# The remaining processing is 6.804099678345814
# machine broken !!!!!!!!! at 1853.7993496156105
# The machine start processing current part at 1850.5658281177293.
# It will take 10.51855400546663 min.
# But the machine was broken at 1853.7993496156105.
# The remaining processing is 7.285032507585473
# machine broken !!!!!!!!! at 1865.931476821288
# The machine start processing current part at 1855.6447926375217.
# It will take 12.705637082230599 min.
# But the machine was broken at 1865.931476821288.
# The remaining processing is 2.4189528984643154
# The machine was repaired at 1881.5048489198523
# machine broken !!!!!!!!! at 1889.0293683128139
# The machine start processing current part at 1886.6815183884185.
# It will take 10.525149519279074 min.
# But the machine was broken at 1889.0293683128139.
# The remaining processing is 8.177299594883669
# machine broken !!!!!!!!! at 1907.174421391006
# The machine start processing current part at 1897.0168713099322.
# It will take 11.011677019295584 min.
# But the machine was broken at 1907.174421391006.
# The remaining processing is 0.854126938221734
# The machine was repaired at 1911.5048489198523
# machine broken !!!!!!!!! at 1933.093301552266
# The machine start processing current part at 1931.5375704184082.
# It will take 10.391263137734166 min.
# But the machine was broken at 1933.093301552266.
# The remaining processing is 8.835532003876404
# The machine was repaired at 1941.5048489198523
# machine broken !!!!!!!!! at 1947.8819879727878
# The machine start processing current part at 1941.5048489198523.
# It will take 7.285032507585473 min.
# But the machine was broken at 1947.8819879727878.
# The remaining processing is 0.9078934546499831
# The machine was repaired at 1971.5048489198523
# The machine was repaired at 2001.5048489198523
# The machine was repaired at 2031.5048489198523
# The machine was repaired at 2061.5048489198525
# machine broken !!!!!!!!! at 2062.302728852177
# The machine start processing current part at 2059.4179024117934.
# It will take 10.562551839744673 min.
# But the machine was broken at 2062.302728852177.
# The remaining processing is 7.677725399360996
# The machine was repaired at 2091.5048489198525
# The machine was repaired at 2121.5048489198525
# leave other_jobs at 2130.0
# done_in at 2130.0
# machine broken !!!!!!!!! at 2134.8339242307256
# The machine start processing current part at 2129.9880619687915.
# It will take 10.150118156449219 min.
# But the machine was broken at 2134.8339242307256.
# The remaining processing is 5.304255894515075
# interrupted during other_jobs at 2134.8339242307256
# done_in at 2134.8339242307256
# The machine was repaired at 2164.8339242307256
# machine broken !!!!!!!!! at 2171.967932563405
# The machine start processing current part at 2162.7263616631312.
# It will take 10.488011936049695 min.
# But the machine was broken at 2171.967932563405.
# The remaining processing is 1.2464410357757671
# interrupted during other_jobs at 2171.967932563405
# done_in at 2171.967932563405
# machine broken !!!!!!!!! at 2199.361587815589
# The machine start processing current part at 2198.4279041904415.
# It will take 12.549755388819092 min.
# But the machine was broken at 2199.361587815589.
# The remaining processing is 11.616071763671796
# The machine was repaired at 2201.967932563405
# The machine was repaired at 2231.967932563405
# machine broken !!!!!!!!! at 2246.6160018575824
# The machine start processing current part at 2242.6141545568394.
# It will take 8.295669544326493 min.
# But the machine was broken at 2246.6160018575824.
# The remaining processing is 4.293822243583428
# interrupted during other_jobs at 2246.6160018575824
# done_in at 2246.6160018575824
# The machine was repaired at 2276.6160018575824
# leave other_jobs at 2280.0
# done_in at 2280.0
# machine broken !!!!!!!!! at 2308.4368008852466
# The machine start processing current part at 2302.8142486153165.
# It will take 9.250277587346652 min.
# But the machine was broken at 2308.4368008852466.
# The remaining processing is 3.627725317416541
# interrupted during other_jobs at 2308.4368008852466
# done_in at 2308.4368008852466
# The machine was repaired at 2338.4368008852466
# leave other_jobs at 2340.0
# done_in at 2340.0
# machine broken !!!!!!!!! at 2368.5129174408507
# The machine start processing current part at 2364.1813481814265.
# It will take 9.857815116228524 min.
# But the machine was broken at 2368.5129174408507.
# The remaining processing is 5.5262458568043105
# interrupted during other_jobs at 2368.5129174408507
# done_in at 2368.5129174408507
# machine broken !!!!!!!!! at 2396.5651879187553
# The machine start processing current part at 2395.115300533333.
# It will take 10.905777651285259 min.
# But the machine was broken at 2396.5651879187553.
# The remaining processing is 9.455890265863015
# The machine was repaired at 2398.5129174408507
# machine broken !!!!!!!!! at 2409.7977317900345
# The machine start processing current part at 2396.0602471232596.
# It will take 14.265339423951033 min.
# But the machine was broken at 2409.7977317900345.
# The remaining processing is 0.5278547571761436
# The machine was repaired at 2428.5129174408507
# The machine was repaired at 2458.5129174408507
# leave other_jobs at 2460.0
# done_in at 2460.0
# machine broken !!!!!!!!! at 2468.818948888624
# The machine start processing current part at 2466.3736603808716.
# It will take 9.40730205591629 min.
# But the machine was broken at 2468.818948888624.
# The remaining processing is 6.962013548163696
# interrupted during other_jobs at 2468.818948888624
# done_in at 2468.818948888624
# The machine was repaired at 2498.818948888624
# leave other_jobs at 2520.0
# done_in at 2520.0
# machine broken !!!!!!!!! at 2536.62485433891
# The machine start processing current part at 2535.6630326884024.
# It will take 10.964006234284968 min.
# But the machine was broken at 2536.62485433891.
# The remaining processing is 10.002184583777195
# interrupted during other_jobs at 2536.62485433891
# done_in at 2536.62485433891
# machine broken !!!!!!!!! at 2537.582668237493
# The machine start processing current part at 2535.331557910605.
# It will take 10.327292313173453 min.
# But the machine was broken at 2537.582668237493.
# The remaining processing is 8.076181986285443
# The machine was repaired at 2566.62485433891
# The machine was repaired at 2596.62485433891
# leave other_jobs at 2610.0
# done_in at 2610.0
# machine broken !!!!!!!!! at 2610.8861809128066
# The machine start processing current part at 2602.159884915091.
# It will take 11.125147725955653 min.
# But the machine was broken at 2610.8861809128066.
# The remaining processing is 2.398851728240029
# interrupted during other_jobs at 2610.8861809128066
# done_in at 2610.8861809128066
# machine broken !!!!!!!!! at 2631.924004722571
# The machine start processing current part at 2628.6213232135174.
# It will take 10.50895816722416 min.
# But the machine was broken at 2631.924004722571.
# The remaining processing is 7.206276658170305
# The machine was repaired at 2640.8861809128066
# machine broken !!!!!!!!! at 2666.310662642245
# The machine start processing current part at 2658.2230910185954.
# It will take 9.245627084917674 min.
# But the machine was broken at 2666.310662642245.
# The remaining processing is 1.1580554612680363
# The machine was repaired at 2670.8861809128066
# machine broken !!!!!!!!! at 2697.21876370575
# The machine start processing current part at 2688.0535653507827.
# It will take 11.560018446949968 min.
# But the machine was broken at 2697.21876370575.
# The remaining processing is 2.3948200919826803
# The machine was repaired at 2700.8861809128066
# The machine was repaired at 2730.8861809128066
# machine broken !!!!!!!!! at 2731.77712220917
# The machine start processing current part at 2725.9515992343577.
# It will take 12.876472472469157 min.
# But the machine was broken at 2731.77712220917.
# The remaining processing is 7.0509494976567275
# interrupted during other_jobs at 2731.77712220917
# done_in at 2731.77712220917
# The machine was repaired at 2761.77712220917
# leave other_jobs at 2790.0
# done_in at 2790.0
# machine broken !!!!!!!!! at 2804.3394164967644
# The machine start processing current part at 2796.0814984682106.
# It will take 12.676754195083962 min.
# But the machine was broken at 2804.3394164967644.
# The remaining processing is 4.418836166530131
# interrupted during other_jobs at 2804.3394164967644
# done_in at 2804.3394164967644
# The machine was repaired at 2834.3394164967644
# machine broken !!!!!!!!! at 2848.7614676647195
# The machine start processing current part at 2848.45987459665.
# It will take 9.531740799338266 min.
# But the machine was broken at 2848.7614676647195.
# The remaining processing is 9.230147731268815
# interrupted during other_jobs at 2848.7614676647195
# done_in at 2848.7614676647195
# machine broken !!!!!!!!! at 2853.06050884586
# The machine start processing current part at 2845.2171072384676.
# It will take 10.314688391975851 min.
# But the machine was broken at 2853.06050884586.
# The remaining processing is 2.4712867845833717
# The machine was repaired at 2878.7614676647195
# machine broken !!!!!!!!! at 2880.477323653984
# The machine start processing current part at 2879.2264351131853.
# It will take 13.344154684376369 min.
# But the machine was broken at 2880.477323653984.
# The remaining processing is 12.0932661435776
# The machine was repaired at 2908.7614676647195
# machine broken !!!!!!!!! at 2915.6323752860226
# The machine start processing current part at 2909.504723797515.
# It will take 9.150292636045045 min.
# But the machine was broken at 2915.6323752860226.
# The remaining processing is 3.0226411475374633
# The machine was repaired at 2938.7614676647195
# machine broken !!!!!!!!! at 2959.830404022175
# The machine start processing current part at 2958.709897269901.
# It will take 10.674965372222873 min.
# But the machine was broken at 2959.830404022175.
# The remaining processing is 9.554458619948678
# The machine was repaired at 2968.7614676647195
# machine broken !!!!!!!!! at 2971.0377739423966
# The machine start processing current part at 2966.027333929498.
# It will take 12.250469120356605 min.
# But the machine was broken at 2971.0377739423966.
# The remaining processing is 7.240029107458135
# The machine was repaired at 2998.7614676647195
# The machine was repaired at 3028.7614676647195
# leave other_jobs at 3030.0
# done_in at 3030.0
# machine broken !!!!!!!!! at 3057.388317427633
# The machine start processing current part at 3055.62358629968.
# It will take 8.496440545719988 min.
# But the machine was broken at 3057.388317427633.
# The remaining processing is 6.73170941776706
# interrupted during other_jobs at 3057.388317427633
# done_in at 3057.388317427633
# machine broken !!!!!!!!! at 3081.248807986745
# The machine start processing current part at 3077.4568053301887.
# It will take 12.251463145453052 min.
# But the machine was broken at 3081.248807986745.
# The remaining processing is 8.459460488896873
# The machine was repaired at 3087.388317427633
# machine broken !!!!!!!!! at 3091.6199558259977
# The machine start processing current part at 3090.5638026662996.
# It will take 11.19832527903418 min.
# But the machine was broken at 3091.6199558259977.
# The remaining processing is 10.14217211933601
# machine broken !!!!!!!!! at 3105.518649883897
# The machine start processing current part at 3096.9509120737325.
# It will take 8.686197152174612 min.
# But the machine was broken at 3105.518649883897.
# The remaining processing is 0.11845934201006791
# The machine was repaired at 3117.388317427633
# machine broken !!!!!!!!! at 3142.0600652229327
# The machine start processing current part at 3140.041212089361.
# It will take 4.355859776286328 min.
# But the machine was broken at 3142.0600652229327.
# The remaining processing is 2.3370066427147176
# The machine was repaired at 3147.388317427633
# The machine was repaired at 3177.388317427633
# machine broken !!!!!!!!! at 3191.8169362993244
# The machine start processing current part at 3187.3259965613806.
# It will take 12.38734382011968 min.
# But the machine was broken at 3191.8169362993244.
# The remaining processing is 7.89640408217589
# The machine was repaired at 3207.388317427633
# machine broken !!!!!!!!! at 3227.058633933973
# The machine start processing current part at 3222.9473443127326.
# It will take 9.117195369659612 min.
# But the machine was broken at 3227.058633933973.
# The remaining processing is 5.005905748419309
# The machine was repaired at 3237.388317427633
# machine broken !!!!!!!!! at 3252.1037291904718
# The machine start processing current part at 3240.247748375223.
# It will take 12.094881475799696 min.
# But the machine was broken at 3252.1037291904718.
# The remaining processing is 0.23890066055110992
# The machine was repaired at 3267.388317427633
# machine broken !!!!!!!!! at 3280.114074657398
# The machine start processing current part at 3278.868059838235.
# It will take 8.482202763242961 min.
# But the machine was broken at 3280.114074657398.
# The remaining processing is 7.236187944079896
# The machine was repaired at 3297.388317427633
# The machine was repaired at 3327.388317427633
# leave other_jobs at 3330.0
# done_in at 3330.0
# machine broken !!!!!!!!! at 3341.1986459480436
# The machine start processing current part at 3339.0610054872495.
# It will take 8.937330785448365 min.
# But the machine was broken at 3341.1986459480436.
# The remaining processing is 6.799690324654319
# interrupted during other_jobs at 3341.1986459480436
# done_in at 3341.1986459480436
# machine broken !!!!!!!!! at 3349.574743829086
# The machine start processing current part at 3346.228774104195.
# It will take 14.951255817936053 min.
# But the machine was broken at 3349.574743829086.
# The remaining processing is 11.60528609304516
# machine broken !!!!!!!!! at 3360.3496378321984
# The machine start processing current part at 3357.1565150237384.
# It will take 9.90012375165531 min.
# But the machine was broken at 3360.3496378321984.
# The remaining processing is 6.707000943195334
# machine broken !!!!!!!!! at 3361.3458243556875
# The machine start processing current part at 3354.2314283651194.
# It will take 11.520358180540427 min.
# But the machine was broken at 3361.3458243556875.
# The remaining processing is 4.405962189972399
# The machine was repaired at 3371.1986459480436
# The machine was repaired at 3401.1986459480436
# machine broken !!!!!!!!! at 3428.8210503259133
# The machine start processing current part at 3418.432368498439.
# It will take 12.476188773012664 min.
# But the machine was broken at 3428.8210503259133.
# The remaining processing is 2.0875069455381077
# The machine was repaired at 3431.1986459480436
# machine broken !!!!!!!!! at 3431.5612475960584
# The machine start processing current part at 3423.7216210659208.
# It will take 11.711544092294952 min.
# But the machine was broken at 3431.5612475960584.
# The remaining processing is 3.8719175621573587
# machine broken !!!!!!!!! at 3458.458721725551
# The machine start processing current part at 3458.008465714656.
# It will take 10.79299197982748 min.
# But the machine was broken at 3458.458721725551.
# The remaining processing is 10.342735968932107
# The machine was repaired at 3461.1986459480436
# The machine was repaired at 3491.1986459480436
# machine broken !!!!!!!!! at 3519.608239133877
# The machine start processing current part at 3516.0957007012835.
# It will take 11.266562386827664 min.
# But the machine was broken at 3519.608239133877.
# The remaining processing is 7.75402395423429
# The machine was repaired at 3521.1986459480436
# machine broken !!!!!!!!! at 3533.3146560500545
# The machine start processing current part at 3533.2508457988915.
# It will take 9.918436555994735 min.
# But the machine was broken at 3533.3146560500545.
# The remaining processing is 9.854626304831758
# machine broken !!!!!!!!! at 3536.4659382240407
# The machine start processing current part at 3530.928769929874.
# It will take 9.847384895959298 min.
# But the machine was broken at 3536.4659382240407.
# The remaining processing is 4.310216601792494
# The machine was repaired at 3551.1986459480436
# The machine was repaired at 3581.1986459480436
# The machine was repaired at 3611.1986459480436
# The machine was repaired at 3641.1986459480436
# leave other_jobs at 3660.0
# done_in at 3660.0
# machine broken !!!!!!!!! at 3683.203107177363
# The machine start processing current part at 3681.4058828928105.
# It will take 9.350999968822007 min.
# But the machine was broken at 3683.203107177363.
# The remaining processing is 7.553775684269395
# interrupted during other_jobs at 3683.203107177363
# done_in at 3683.203107177363
# machine broken !!!!!!!!! at 3706.0511092351926
# The machine start processing current part at 3698.802230290113.
# It will take 12.98293484186736 min.
# But the machine was broken at 3706.0511092351926.
# The remaining processing is 5.734055896787892
# machine broken !!!!!!!!! at 3708.8239014067913
# The machine start processing current part at 3700.6521094531304.
# It will take 13.298761408859324 min.
# But the machine was broken at 3708.8239014067913.
# The remaining processing is 5.126969455198438
# The machine was repaired at 3713.203107177363
# The machine was repaired at 3743.203107177363
# The machine was repaired at 3773.203107177363
# leave other_jobs at 3780.0
# done_in at 3780.0
# machine broken !!!!!!!!! at 3785.8613616774664
# The machine start processing current part at 3778.740717333113.
# It will take 11.672116006760147 min.
# But the machine was broken at 3785.8613616774664.
# The remaining processing is 4.551471662406724
# interrupted during other_jobs at 3785.8613616774664
# done_in at 3785.8613616774664
# machine broken !!!!!!!!! at 3796.956454403365
# The machine start processing current part at 3791.817895056677.
# It will take 7.112134753612061 min.
# But the machine was broken at 3796.956454403365.
# The remaining processing is 1.9735754069240627
# The machine was repaired at 3815.8613616774664
# The machine was repaired at 3845.8613616774664
# leave other_jobs at 3870.0
# done_in at 3870.0
# machine broken !!!!!!!!! at 3872.7051328959287
# The machine start processing current part at 3868.2009655866214.
# It will take 7.053131220618697 min.
# But the machine was broken at 3872.7051328959287.
# The remaining processing is 2.5489639113113203
# interrupted during other_jobs at 3872.7051328959287
# done_in at 3872.7051328959287
# machine broken !!!!!!!!! at 3874.833855410361
# The machine start processing current part at 3874.057078734211.
# It will take 7.605117758167481 min.
# But the machine was broken at 3874.833855410361.
# The remaining processing is 6.828341082017133
# The machine was repaired at 3902.7051328959287
# The machine was repaired at 3932.7051328959287
# leave other_jobs at 3960.0
# done_in at 3960.0
# machine broken !!!!!!!!! at 3975.497573725754
# The machine start processing current part at 3971.3365434675234.
# It will take 7.452135100286327 min.
# But the machine was broken at 3975.497573725754.
# The remaining processing is 3.29110484205556
# interrupted during other_jobs at 3975.497573725754
# done_in at 3975.497573725754
# The machine was repaired at 4005.497573725754
# leave other_jobs at 4020.0
# done_in at 4020.0
# machine broken !!!!!!!!! at 4020.067758173538
# The machine start processing current part at 4014.3845234427276.
# It will take 11.97359282866123 min.
# But the machine was broken at 4020.067758173538.
# The remaining processing is 6.290358097850776
# interrupted during other_jobs at 4020.067758173538
# done_in at 4020.067758173538
# The machine was repaired at 4050.067758173538
# machine broken !!!!!!!!! at 4057.89594268664
# The machine start processing current part at 4047.854592355811.
# It will take 10.210001365293477 min.
# But the machine was broken at 4057.89594268664.
# The remaining processing is 0.16865103446435903
# interrupted during other_jobs at 4057.89594268664
# done_in at 4057.89594268664
# machine broken !!!!!!!!! at 4062.972929035353
# The machine start processing current part at 4056.3237822453207.
# It will take 10.015272843148521 min.
# But the machine was broken at 4062.972929035353.
# The remaining processing is 3.3661260531162025
# machine broken !!!!!!!!! at 4069.4870370758545
# The machine start processing current part at 4064.250445886439.
# It will take 9.96133167574759 min.
# But the machine was broken at 4069.4870370758545.
# The remaining processing is 4.724740486332269
# The machine was repaired at 4087.89594268664
# The machine was repaired at 4117.89594268664
# The machine was repaired at 4147.89594268664
# leave other_jobs at 4170.0
# done_in at 4170.0
# machine broken !!!!!!!!! at 4183.670484417873
# The machine start processing current part at 4181.24778714509.
# It will take 8.189925110185765 min.
# But the machine was broken at 4183.670484417873.
# The remaining processing is 5.767227837402867
# interrupted during other_jobs at 4183.670484417873
# done_in at 4183.670484417873
# The machine was repaired at 4213.670484417873
# leave other_jobs at 4230.0
# done_in at 4230.0
# leave other_jobs at 4260.0
# done_in at 4260.0
# machine broken !!!!!!!!! at 4262.527604675551
# The machine start processing current part at 4261.1973950161155.
# It will take 10.012496127637553 min.
# But the machine was broken at 4262.527604675551.
# The remaining processing is 8.682286468202312
# interrupted during other_jobs at 4262.527604675551
# done_in at 4262.527604675551
# machine broken !!!!!!!!! at 4289.200740546099
# The machine start processing current part at 4286.194115047663.
# It will take 9.079225919945653 min.
# But the machine was broken at 4289.200740546099.
# The remaining processing is 6.072600421509829
# The machine was repaired at 4292.527604675551
# The machine was repaired at 4322.527604675551
# machine broken !!!!!!!!! at 4330.806741464446
# The machine start processing current part at 4324.36737521752.
# It will take 10.42623046462171 min.
# But the machine was broken at 4330.806741464446.
# The remaining processing is 3.986864217696109
# interrupted during other_jobs at 4330.806741464446
# done_in at 4330.806741464446
# The machine was repaired at 4360.806741464446
# machine broken !!!!!!!!! at 4365.80120610288
# The machine start processing current part at 4365.107463363092.
# It will take 8.46465019604858 min.
# But the machine was broken at 4365.80120610288.
# The remaining processing is 7.770907456260659
# interrupted during other_jobs at 4365.80120610288
# done_in at 4365.80120610288
# The machine was repaired at 4395.80120610288
# machine broken !!!!!!!!! at 4396.5628944916025
# The machine start processing current part at 4394.915301175007.
# It will take 8.796657221726413 min.
# But the machine was broken at 4396.5628944916025.
# The remaining processing is 7.14906390513071
# interrupted during other_jobs at 4396.5628944916025
# done_in at 4396.5628944916025
# The machine was repaired at 4426.5628944916025
# leave other_jobs at 4440.0
# done_in at 4440.0
# machine broken !!!!!!!!! at 4452.928233984154
# The machine start processing current part at 4448.81720613402.
# It will take 9.115345036852101 min.
# But the machine was broken at 4452.928233984154.
# The remaining processing is 5.004317186718378
# interrupted during other_jobs at 4452.928233984154
# done_in at 4452.928233984154
# The machine was repaired at 4482.928233984154
# machine broken !!!!!!!!! at 4493.4968275742285
# The machine start processing current part at 4484.4048533243185.
# It will take 10.227687287493447 min.
# But the machine was broken at 4493.4968275742285.
# The remaining processing is 1.135713037583466
# interrupted during other_jobs at 4493.4968275742285
# done_in at 4493.4968275742285
# machine broken !!!!!!!!! at 4499.545838783562
# The machine start processing current part at 4491.137160485671.
# It will take 9.824943881819028 min.
# But the machine was broken at 4499.545838783562.
# The remaining processing is 1.416265583927899
# machine broken !!!!!!!!! at 4508.909476811585
# The machine start processing current part at 4508.067783592878.
# It will take 7.165731532262663 min.
# But the machine was broken at 4508.909476811585.
# The remaining processing is 6.3240383135561675
# machine broken !!!!!!!!! at 4522.591520822817
# The machine start processing current part at 4515.036335710142.
# It will take 10.417451716683978 min.
# But the machine was broken at 4522.591520822817.
# The remaining processing is 2.8622666040092426
# The machine was repaired at 4523.4968275742285
# machine broken !!!!!!!!! at 4531.639261965042
# The machine start processing current part at 4524.5354752711355.
# It will take 12.468304475274866 min.
# But the machine was broken at 4531.639261965042.
# The remaining processing is 5.364517781368026
# The machine was repaired at 4553.4968275742285
# machine broken !!!!!!!!! at 4562.249236227134
# The machine start processing current part at 4559.250155715651.
# It will take 9.580747093537138 min.
# But the machine was broken at 4562.249236227134.
# The remaining processing is 6.581666582054094
# The machine was repaired at 4583.4968275742285
# machine broken !!!!!!!!! at 4599.110113552302
# The machine start processing current part at 4595.037834491919.
# It will take 11.26607579775336 min.
# But the machine was broken at 4599.110113552302.
# The remaining processing is 7.1937967373702065
# machine broken !!!!!!!!! at 4612.164945655714
# The machine start processing current part at 4611.8378458242905.
# It will take 10.414673614114154 min.
# But the machine was broken at 4612.164945655714.
# The remaining processing is 10.087573782690388
# The machine was repaired at 4613.4968275742285
# The machine was repaired at 4643.4968275742285
# machine broken !!!!!!!!! at 4647.182774310463
# The machine start processing current part at 4634.426899716493.
# It will take 13.399577880703017 min.
# But the machine was broken at 4647.182774310463.
# The remaining processing is 0.6437032867325421
# machine broken !!!!!!!!! at 4647.763917649765
# The machine start processing current part at 4645.457190005492.
# It will take 8.645581168559914 min.
# But the machine was broken at 4647.763917649765.
# The remaining processing is 6.338853524286463
# The machine was repaired at 4673.4968275742285
# The machine was repaired at 4703.4968275742285
# The machine was repaired at 4733.4968275742285
# machine broken !!!!!!!!! at 4748.429978531743
# The machine start processing current part at 4747.470104423469.
# It will take 10.801646017575496 min.
# But the machine was broken at 4748.429978531743.
# The remaining processing is 9.841771909301844
# machine broken !!!!!!!!! at 4757.698179482423
# The machine start processing current part at 4753.06382822064.
# It will take 7.6834866248286815 min.
# But the machine was broken at 4757.698179482423.
# The remaining processing is 3.0491353630454867
# The machine was repaired at 4763.4968275742285
# machine broken !!!!!!!!! at 4773.811135341903
# The machine start processing current part at 4767.163709027358.
# It will take 11.639162294834072 min.
# But the machine was broken at 4773.811135341903.
# The remaining processing is 4.991735980289427
# The machine was repaired at 4793.4968275742285
# The machine was repaired at 4823.4968275742285
# machine broken !!!!!!!!! at 4844.779395596702
# The machine start processing current part at 4842.492061458176.
# It will take 13.804318185904993 min.
# But the machine was broken at 4844.779395596702.
# The remaining processing is 11.5169840473793
# The machine was repaired at 4853.4968275742285
# machine broken !!!!!!!!! at 4875.573335073706
# The machine start processing current part at 4861.686613288393.
# It will take 14.782436068662879 min.
# But the machine was broken at 4875.573335073706.
# The remaining processing is 0.8957142833498217
# The machine was repaired at 4883.4968275742285
# machine broken !!!!!!!!! at 4898.5973512847795
# The machine start processing current part at 4894.891640097178.
# It will take 9.153293787229124 min.
# But the machine was broken at 4898.5973512847795.
# The remaining processing is 5.447582599628042
# The machine was repaired at 4913.4968275742285
# machine broken !!!!!!!!! at 4920.185784109371
# The machine start processing current part at 4912.359111494944.
# It will take 10.392957625287597 min.
# But the machine was broken at 4920.185784109371.
# The remaining processing is 2.5662850108610264
# The machine was repaired at 4943.4968275742285
# machine broken !!!!!!!!! at 4946.103270715716
# The machine start processing current part at 4942.059063876037.
# It will take 12.21156963179782 min.
# But the machine was broken at 4946.103270715716.
# The remaining processing is 8.167362792119084
# The machine was repaired at 4973.4968275742285
# The machine was repaired at 5003.4968275742285
# The machine was repaired at 5033.4968275742285
# leave other_jobs at 5040.0
# done_in at 5040.0
# machine broken !!!!!!!!! at 5042.697698300038
# The machine start processing current part at 5041.664190366348.
# It will take 9.229398616855539 min.
# But the machine was broken at 5042.697698300038.
# The remaining processing is 8.19589068316545
# interrupted during other_jobs at 5042.697698300038
# done_in at 5042.697698300038
# machine broken !!!!!!!!! at 5057.925506639153
# The machine start processing current part at 5056.895604558417.
# It will take 9.284023568028717 min.
# But the machine was broken at 5057.925506639153.
# The remaining processing is 8.254121487292652
# The machine was repaired at 5072.697698300038
# The machine was repaired at 5102.697698300038
# leave other_jobs at 5130.0
# done_in at 5130.0
# machine broken !!!!!!!!! at 5154.546966580059
# The machine start processing current part at 5146.9861474860245.
# It will take 12.748307449764372 min.
# But the machine was broken at 5154.546966580059.
# The remaining processing is 5.187488355729631
# interrupted during other_jobs at 5154.546966580059
# done_in at 5154.546966580059
# The machine was repaired at 5184.546966580059
# machine broken !!!!!!!!! at 5186.310070041046
# The machine start processing current part at 5185.456752492677.
# It will take 8.25581423845316 min.
# But the machine was broken at 5186.310070041046.
# The remaining processing is 7.402496690084183
# interrupted during other_jobs at 5186.310070041046
# done_in at 5186.310070041046
# The machine was repaired at 5216.310070041046
# leave other_jobs at 5220.0
# done_in at 5220.0
# leave other_jobs at 5250.0
# done_in at 5250.0
# machine broken !!!!!!!!! at 5278.545080068283
# The machine start processing current part at 5274.235188217487.
# It will take 14.42665170151622 min.
# But the machine was broken at 5278.545080068283.
# The remaining processing is 10.116759850720427
# interrupted during other_jobs at 5278.545080068283
# done_in at 5278.545080068283
# machine broken !!!!!!!!! at 5294.356384720209
# The machine start processing current part at 5292.114857537024.
# It will take 9.167115081559675 min.
# But the machine was broken at 5294.356384720209.
# The remaining processing is 6.925587898375486
# machine broken !!!!!!!!! at 5301.629856106607
# The machine start processing current part at 5298.592733656258.
# It will take 8.718033568311405 min.
# But the machine was broken at 5301.629856106607.
# The remaining processing is 5.680911117962644
# The machine was repaired at 5308.545080068283
# The machine was repaired at 5338.545080068283
# The machine was repaired at 5368.545080068283
# machine broken !!!!!!!!! at 5369.727019175705
# The machine start processing current part at 5367.064543249219.
# It will take 11.44032950971155 min.
# But the machine was broken at 5369.727019175705.
# The remaining processing is 8.777853583225582
# interrupted during other_jobs at 5369.727019175705
# done_in at 5369.727019175705
# machine broken !!!!!!!!! at 5370.61745194416
# The machine start processing current part at 5368.947454801374.
# It will take 9.39859386956972 min.
# But the machine was broken at 5370.61745194416.
# The remaining processing is 7.728596726783632
# machine broken !!!!!!!!! at 5394.383453866197
# The machine start processing current part at 5386.988891618093.
# It will take 8.238808478985707 min.
# But the machine was broken at 5394.383453866197.
# The remaining processing is 0.8442462308815131
# The machine was repaired at 5399.727019175705
# The machine was repaired at 5429.727019175705
# machine broken !!!!!!!!! at 5439.786913471649
# The machine start processing current part at 5437.455615902489.
# It will take 9.572965380153894 min.
# But the machine was broken at 5439.786913471649.
# The remaining processing is 7.241667810993297
# The machine was repaired at 5459.727019175705
# machine broken !!!!!!!!! at 5483.19774384375
# The machine start processing current part at 5477.813595189537.
# It will take 9.345043099662634 min.
# ...
# The remaining processing is 9.595828571425526
# machine broken !!!!!!!!! at 38722.14210289907
# The machine start processing current part at 38720.96341029136.
# It will take 9.27530629473014 min.
# But the machine was broken at 38722.14210289907.
# The remaining processing is 8.096613687019012
# machine broken !!!!!!!!! at 38738.89227152997
# The machine start processing current part at 38729.298207024774.
# It will take 11.383654904487718 min.
# But the machine was broken at 38738.89227152997.
# The remaining processing is 1.7895903992917166
# The machine was repaired at 38740.25093491585
# The machine was repaired at 38770.25093491585
# The machine was repaired at 38800.25093491585
# machine broken !!!!!!!!! at 38802.45930898969
# The machine start processing current part at 38794.6183946432.
# It will take 8.371108763582855 min.
# But the machine was broken at 38802.45930898969.
# The remaining processing is 0.5301944170941386
# The machine was repaired at 38830.25093491585
# machine broken !!!!!!!!! at 38835.518907768936
# The machine start processing current part at 38826.37433113317.
# It will take 11.385151471119775 min.
# But the machine was broken at 38835.518907768936.
# The remaining processing is 2.240574835355096
# machine broken !!!!!!!!! at 38852.23649605121
# The machine start processing current part at 38847.23229021211.
# It will take 9.767238927640047 min.
# But the machine was broken at 38852.23649605121.
# The remaining processing is 4.763033088535504
# The machine was repaired at 38860.25093491585
# The machine was repaired at 38890.25093491585
# The machine was repaired at 38920.25093491585
# leave other_jobs at 38940.0
# done_in at 38940.0
# machine broken !!!!!!!!! at 38952.91165609177
# The machine start processing current part at 38945.45512824997.
# It will take 7.601709247047164 min.
# But the machine was broken at 38952.91165609177.
# The remaining processing is 0.1451814052458742
# interrupted during other_jobs at 38952.91165609177
# done_in at 38952.91165609177
# machine broken !!!!!!!!! at 38976.87020350267
# The machine start processing current part at 38971.61957105103.
# It will take 12.709994304375252 min.
# But the machine was broken at 38976.87020350267.
# The remaining processing is 7.459361852731783
# The machine was repaired at 38982.91165609177
# The machine was repaired at 39012.91165609177
# machine broken !!!!!!!!! at 39014.10263987406
# The machine start processing current part at 39011.330849059465.
# It will take 10.564257801422634 min.
# But the machine was broken at 39014.10263987406.
# The remaining processing is 7.792466986829375
# interrupted during other_jobs at 39014.10263987406
# done_in at 39014.10263987406
# machine broken !!!!!!!!! at 39028.69119765445
# The machine start processing current part at 39018.434772411456.
# It will take 11.819571734770465 min.
# But the machine was broken at 39028.69119765445.
# The remaining processing is 1.5631464917757274
# machine broken !!!!!!!!! at 39036.38095667237
# The machine start processing current part at 39030.95154930683.
# It will take 10.904218753507465 min.
# But the machine was broken at 39036.38095667237.
# The remaining processing is 5.474811387967364
# The machine was repaired at 39044.10263987406
# machine broken !!!!!!!!! at 39061.90224688512
# The machine start processing current part at 39061.22645293618.
# It will take 10.043670109874103 min.
# But the machine was broken at 39061.90224688512.
# The remaining processing is 9.367876160934276
# The machine was repaired at 39074.10263987406
# machine broken !!!!!!!!! at 39074.54399693306
# The machine start processing current part at 39072.68195876254.
# It will take 7.599647201248334 min.
# But the machine was broken at 39074.54399693306.
# The remaining processing is 5.737609030729689
# machine broken !!!!!!!!! at 39081.8287854875
# The machine start processing current part at 39075.63764640859.
# It will take 10.847035913296793 min.
# But the machine was broken at 39081.8287854875.
# The remaining processing is 4.655896834386738
# machine broken !!!!!!!!! at 39101.03580076114
# The machine start processing current part at 39089.25951427687.
# It will take 13.054862453417345 min.
# But the machine was broken at 39101.03580076114.
# The remaining processing is 1.278575969143903
# The machine was repaired at 39104.10263987406
# machine broken !!!!!!!!! at 39117.0725926548
# The machine start processing current part at 39109.57745126203.
# It will take 13.019161121794156 min.
# But the machine was broken at 39117.0725926548.
# The remaining processing is 5.5240197290239905
# The machine was repaired at 39134.10263987406
# The machine was repaired at 39164.10263987406
# The machine was repaired at 39194.10263987406
# machine broken !!!!!!!!! at 39194.80498134167
# The machine start processing current part at 39188.16538155903.
# It will take 9.615403854562532 min.
# But the machine was broken at 39194.80498134167.
# The remaining processing is 2.9758040719222425
# machine broken !!!!!!!!! at 39213.56959106797
# The machine start processing current part at 39212.34012135837.
# It will take 7.7962784721999245 min.
# But the machine was broken at 39213.56959106797.
# The remaining processing is 6.566808762599544
# The machine was repaired at 39224.10263987406
# machine broken !!!!!!!!! at 39233.75355260308
# The machine start processing current part at 39233.56672573699.
# It will take 7.819535922389976 min.
# But the machine was broken at 39233.75355260308.
# The remaining processing is 7.632709056306256
# The machine was repaired at 39254.10263987406
# machine broken !!!!!!!!! at 39264.88818757504
# The machine start processing current part at 39259.3986524859.
# It will take 10.671452718431103 min.
# But the machine was broken at 39264.88818757504.
# The remaining processing is 5.181917629292732
# machine broken !!!!!!!!! at 39278.27890469676
# The machine start processing current part at 39277.99586519167.
# It will take 10.679545090544888 min.
# But the machine was broken at 39278.27890469676.
# The remaining processing is 10.39650558545345
# The machine was repaired at 39284.10263987406
# machine broken !!!!!!!!! at 39286.62108664523
# The machine start processing current part at 39278.52575395863.
# It will take 12.020608051606652 min.
# But the machine was broken at 39286.62108664523.
# The remaining processing is 3.9252753650064935
# The machine was repaired at 39314.10263987406
# The machine was repaired at 39344.10263987406
# machine broken !!!!!!!!! at 39354.47269869887
# The machine start processing current part at 39352.71200666155.
# It will take 11.541588782975445 min.
# But the machine was broken at 39354.47269869887.
# The remaining processing is 9.780896745660861
# The machine was repaired at 39374.10263987406
# machine broken !!!!!!!!! at 39386.81157034517
# The machine start processing current part at 39382.99415216829.
# It will take 12.681202303468643 min.
# But the machine was broken at 39386.81157034517.
# The remaining processing is 8.863784126591389
# The machine was repaired at 39404.10263987406
# machine broken !!!!!!!!! at 39433.64403196302
# The machine start processing current part at 39432.87760183779.
# It will take 10.315882564083115 min.
# But the machine was broken at 39433.64403196302.
# The remaining processing is 9.549452438853297
# The machine was repaired at 39434.10263987406
# machine broken !!!!!!!!! at 39441.09035265369
# The machine start processing current part at 39436.26238185549.
# It will take 8.148816067686496 min.
# But the machine was broken at 39441.09035265369.
# The remaining processing is 3.3208452694863837
# The machine was repaired at 39464.10263987406
# machine broken !!!!!!!!! at 39477.01957952211
# The machine start processing current part at 39473.40690430874.
# It will take 11.428402730107196 min.
# But the machine was broken at 39477.01957952211.
# The remaining processing is 7.815727516735793
# The machine was repaired at 39494.10263987406
# machine broken !!!!!!!!! at 39511.300434957295
# The machine start processing current part at 39507.042091175485.
# It will take 11.064847932095445 min.
# But the machine was broken at 39511.300434957295.
# The remaining processing is 6.806504150285191
# The machine was repaired at 39524.10263987406
# The machine was repaired at 39554.10263987406
# machine broken !!!!!!!!! at 39578.608208937854
# The machine start processing current part at 39572.849318423905.
# It will take 11.880020885438588 min.
# But the machine was broken at 39578.608208937854.
# The remaining processing is 6.121130371489434
# The machine was repaired at 39584.10263987406
# machine broken !!!!!!!!! at 39611.1397019081
# The machine start processing current part at 39611.138878128804.
# It will take 10.156309263936533 min.
# But the machine was broken at 39611.1397019081.
# The remaining processing is 10.155485484642965
# The machine was repaired at 39614.10263987406
# The machine was repaired at 39644.10263987406
# The machine was repaired at 39674.10263987406
# machine broken !!!!!!!!! at 39687.877753582376
# The machine start processing current part at 39679.13133582831.
# It will take 10.492190202040147 min.
# But the machine was broken at 39687.877753582376.
# The remaining processing is 1.7457724479723407
# interrupted during other_jobs at 39687.877753582376
# done_in at 39687.877753582376
# machine broken !!!!!!!!! at 39698.085628272056
# The machine start processing current part at 39696.10349769708.
# It will take 7.847645409822708 min.
# But the machine was broken at 39698.085628272056.
# The remaining processing is 5.865514834843471
# machine broken !!!!!!!!! at 39700.8265674677
# The machine start processing current part at 39698.78401406896.
# It will take 7.9293501664235535 min.
# But the machine was broken at 39700.8265674677.
# The remaining processing is 5.886796767679932
# machine broken !!!!!!!!! at 39710.81841507279
# The machine start processing current part at 39709.9682272563.
# It will take 11.815416209025305 min.
# But the machine was broken at 39710.81841507279.
# The remaining processing is 10.965228392535526
# The machine was repaired at 39717.877753582376
# The machine was repaired at 39747.877753582376
# The machine was repaired at 39777.877753582376
# machine broken !!!!!!!!! at 39796.11581513954
# The machine start processing current part at 39791.25307205786.
# It will take 11.694108992706457 min.
# But the machine was broken at 39796.11581513954.
# The remaining processing is 6.831365911021418
# machine broken !!!!!!!!! at 39800.53310303036
# The machine start processing current part at 39797.81324556344.
# It will take 12.265298778789418 min.
# But the machine was broken at 39800.53310303036.
# The remaining processing is 9.545441311872981
# The machine was repaired at 39807.877753582376
# The machine was repaired at 39837.877753582376
# The machine was repaired at 39867.877753582376
# leave other_jobs at 39870.0
# done_in at 39870.0
# machine broken !!!!!!!!! at 39891.14999878625
# The machine start processing current part at 39890.989038855485.
# It will take 12.15442936979058 min.
# But the machine was broken at 39891.14999878625.
# The remaining processing is 11.993469439027525
# interrupted during other_jobs at 39891.14999878625
# done_in at 39891.14999878625
# machine broken !!!!!!!!! at 39920.44559209393
# The machine start processing current part at 39915.51422400123.
# It will take 10.402550567906415 min.
# But the machine was broken at 39920.44559209393.
# The remaining processing is 5.471182475205692
# The machine was repaired at 39921.14999878625
# The machine was repaired at 39951.14999878625
# leave other_jobs at 39960.0
# done_in at 39960.0
# machine broken !!!!!!!!! at 39972.56618112307
# The machine start processing current part at 39968.919406802175.
# It will take 8.948423497116792 min.
# But the machine was broken at 39972.56618112307.
# The remaining processing is 5.301649176224501
# interrupted during other_jobs at 39972.56618112307
# done_in at 39972.56618112307
# The machine was repaired at 40002.56618112307
# leave other_jobs at 40020.0
# done_in at 40020.0
# machine broken !!!!!!!!! at 40030.14721719308
# The machine start processing current part at 40027.91957319781.
# It will take 12.150598926983536 min.
# But the machine was broken at 40030.14721719308.
# The remaining processing is 9.922954931714218
# interrupted during other_jobs at 40030.14721719308
# done_in at 40030.14721719308
# machine broken !!!!!!!!! at 40042.20473907115
# The machine start processing current part at 40038.228730938674.
# It will take 8.928473239514448 min.
# But the machine was broken at 40042.20473907115.
# The remaining processing is 4.952465107035993
# machine broken !!!!!!!!! at 40052.03241336917
# The machine start processing current part at 40049.22570978551.
# It will take 7.988748900768426 min.
# But the machine was broken at 40052.03241336917.
# The remaining processing is 5.1820453171109175
# machine broken !!!!!!!!! at 40056.61632512466
# The machine start processing current part at 40049.188047522206.
# It will take 8.070631422637048 min.
# But the machine was broken at 40056.61632512466.
# The remaining processing is 0.6423538201814107
# The machine was repaired at 40060.14721719308
# machine broken !!!!!!!!! at 40072.42849333161
# The machine start processing current part at 40062.204930066444.
# It will take 10.60795355403571 min.
# But the machine was broken at 40072.42849333161.
# The remaining processing is 0.38439028887115256
# The machine was repaired at 40090.14721719308
# machine broken !!!!!!!!! at 40103.43945740338
# The machine start processing current part at 40095.56212336616.
# It will take 13.071458138932002 min.
# But the machine was broken at 40103.43945740338.
# The remaining processing is 5.1941241017111395
# The machine was repaired at 40120.14721719308
# machine broken !!!!!!!!! at 40146.852028051646
# The machine start processing current part at 40146.053995521885.
# It will take 6.926853085757346 min.
# But the machine was broken at 40146.852028051646.
# The remaining processing is 6.1288205559960875
# The machine was repaired at 40150.14721719308
# machine broken !!!!!!!!! at 40160.93468897019
# The machine start processing current part at 40158.418181784.
# It will take 11.410565091684646 min.
# But the machine was broken at 40160.93468897019.
# The remaining processing is 8.894057905492616
# The machine was repaired at 40180.14721719308
# The machine was repaired at 40210.14721719308
# machine broken !!!!!!!!! at 40222.89368589908
# The machine start processing current part at 40215.34134129479.
# It will take 8.33310378849217 min.
# But the machine was broken at 40222.89368589908.
# The remaining processing is 0.78075918420598
# machine broken !!!!!!!!! at 40225.32277095488
# The machine start processing current part at 40225.28016466976.
# It will take 8.07525891634662 min.
# But the machine was broken at 40225.32277095488.
# The remaining processing is 8.032652631228238
# The machine was repaired at 40240.14721719308
# machine broken !!!!!!!!! at 40250.870830453125
# The machine start processing current part at 40244.39441042386.
# It will take 10.817882185909951 min.
# But the machine was broken at 40250.870830453125.
# The remaining processing is 4.3414621566469975
# The machine was repaired at 40270.14721719308
# machine broken !!!!!!!!! at 40278.06035008661
# The machine start processing current part at 40276.225424661316.
# It will take 11.177752645154122 min.
# But the machine was broken at 40278.06035008661.
# The remaining processing is 9.342827219857007
# The machine was repaired at 40300.14721719308
# machine broken !!!!!!!!! at 40310.87327242722
# The machine start processing current part at 40304.09362059766.
# It will take 9.289021372809788 min.
# But the machine was broken at 40310.87327242722.
# The remaining processing is 2.5093695432516547
# Machine shop results after 40320 minutes
# Machine 0 made 3251 parts.
# Machine 1 made 3273 parts.
# Machine 2 made 3242 parts.
# Machine 3 made 3343 parts.
# Machine 4 made 3387 parts.
# Machine 5 made 3244 parts.
# Machine 6 made 3269 parts.
# Machine 7 made 3185 parts.
# Machine 8 made 3302 parts.
# Machine 9 made 3279 parts.
# Machine 0 has broken 119 times.
# Machine 1 has broken 114 times.
# Machine 2 has broken 116 times.
# Machine 3 has broken 101 times.
# Machine 4 has broken 95 times.
# Machine 5 has broken 123 times.
# Machine 6 has broken 116 times.
# Machine 7 has broken 130 times.
# Machine 8 has broken 113 times.
# Machine 9 has broken 112 times.
